# %%
import os

# %%
# %pip install langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 9.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/15.5 MB 9.2 MB/s eta 0:00:02
#    ------ --------------------------------- 2.6/15.5 MB 8.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/15.5 MB 6.5 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 6.5 MB/s eta 0:00:02
#    -------------- ------------------------- 5.8/15.5 MB 5.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.6/15.5 MB 5.2 MB/s eta 0:00:02
#    -------------------- ------------------- 7.9/15.5 MB 5.2 MB/s eta 0:00:02
#    ------------------------ --------------- 9.4/15.5 MB 5.5 MB/s eta 0:00:02
# ...

# %%
from langchain.llms import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain.llms import OpenAI
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain\llms\__init__.py:545, in __getattr__(name)
#     544 def __getattr__(name: str) -> Any:
# --> 545     from langchain_community import llms
#     547     # If not in interactive env, raise warning.
#     548     if not is_interactive_env():
#
# ModuleNotFoundError: No module named 'langchain_community'
